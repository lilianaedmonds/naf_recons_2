# %%
import sys, os
from pathlib import Path

parent_folder = str(Path.cwd().parents[2])
if parent_folder not in sys.path:
    sys.path.append(parent_folder)
from sigpy import mri
import scipy
import pickle
from sklearn.decomposition import PCA
from matplotlib.colors import ListedColormap
import seaborn as sns
import sigpy as sp
import cupy as cp
import numpy as np
from sigpy.mri.app import L1WaveletRecon


## My files
import save_data_helpers
import recon_functions
import recon_plot_helpers
from gating_functions import golden_angle_coords_3d
import sigpy.plot as pl

# %%
recon_3iters_alpha01 = save_data_helpers.read_pickle('/home/lilianae/projects/naf_clean/final_img_4iters_l1_lam1e-2_alpha0.1')
recon_3iters_alpha03 = save_data_helpers.read_pickle('/home/lilianae/projects/naf_clean/final_img_3iters_l1_lam5e-3')

# %%
print(recon_3iters_alpha01.shape)
# Out:
# (58, 512, 512)

# %%
recon_plot_helpers.plot_recons_all_axes(np.abs(recon_3iters_alpha01), title='L1 3 iters')
recon_plot_helpers.plot_recons_all_axes(np.abs(recon_3iters_alpha03), title='L1 3 iters')
# Out:
# (<Figure size 1500x500 with 3 Axes>,
#  array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object))
